# %% [markdown]
# <a href="https://www.nvidia.com/dli"><img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/></a>

# %% [markdown]
# ## Assessment: Enhancing Data Science Outcomes With Efficient Workflow ##
# In this notebook, you will utilize what you've learned in this workshop to complete an assessment. The assessment has been divided into a couple of steps to guide your development. You will be graded based on the performance of your classification model. Note that this coding portion does not give partial credit - it shows up as either 0 or 60 points.
# <table border="1" class="dataframe" align='left'>  <thead>    <tr style="text-align: right;">      <th>Step</th>      <th></th>      <th>Points</th>    </tr>  </thead>  <tbody>    <tr>      <td>0. Setting Up</td>      <td></td>      <td></td>    </tr>    <tr>      <td>1. Data Loading</td>      <td></td>      <td></td>    </tr>    <tr>      <td>2. Feature Engineering</td>      <td></td>      <td></td>    </tr>    <tr>      <td>3. Model Development</td>      <td></td>      <td></td>    </tr>    <tr>      <td>4. Model Persistence</td>      <td></td>      <td>60</td>    </tr></tbody></table>

# %% [markdown]
# <p><img src='images/pipeline_overview.png' width=720></p>

# %% [markdown]
# ### Step 0: Setting Up ###
# For the assessment we are asking you to create a classification model over a similar dataset as the workshop. You'll need to leverage distributed computing with a Dask cluster of GPU workers. Your task is to prepare and train a classifier that accurately predicts a binary outcome.
#
# **Instructions**: <br>
# 0.1 Modify the `<FIXME>` only and execute the below cell to create a CUDA cluster. <br>
# 0.2 Modify the `<FIXME>` only and execute the cell below to instantiate a Dask client that connects to the CUDA cluster. <br>
# 0.3 Execute the cell below to import the other dependencies.

# %%
# 0.1
# import dependencies
from dask_cuda import LocalCUDACluster

# instantiate a Client
cluster=LocalCUDACluster()
# Out:
# 2025-01-15 21:42:46,898 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2025-01-15 21:42:46,898 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2025-01-15 21:42:46,905 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2025-01-15 21:42:46,906 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2025-01-15 21:42:46,929 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2025-01-15 21:42:46,929 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2025-01-15 21:42:46,930 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2025-01-15 21:42:46,930 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize

# %%
# 0.2
# import dependencies
from dask.distributed import Client, wait
client=Client(cluster)

# %%
# 0.3
# DO NOT CHANGE THIS CELL
# import dependencies
from dask_ml.model_selection import train_test_split
from dask_ml.metrics import accuracy_score
import xgboost

import dask_cudf
import cudf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 1: Data Preparation ###
# The first step is to prepare the data.
#
# **Instructions**: <br>
# 1.1 Modify the `<FIXME>` only and execute the below cell to import data from the given parquet files. <br>
# 1.2 Execute the cell below to persist the data in memory and preview the `dask_cudf.DataFrame`. <br>
# 1.3 Modify the `<FIXME>` only and execute the cell below to check for null values. <br>

# %%
# 1.1
data_dir='data'
ddf=dask_cudf.read_parquet(data_dir)

print(f'Total of {len(ddf)} records split across {ddf.npartitions} partitions. ')
# Out:
# Total of 2461697 records split across 4 partitions.

# %%
# 1.2
# DO NOT CHANGE THIS CELL
# persist data
ddf=ddf.persist()
wait(ddf)

print(f'Columns: {ddf.columns}')

ddf.head()
# Out:
# Columns: Index(['brand', 'cat_0', 'cat_1', 'cat_2', 'cat_3', 'price', 'ts_hour',
#        'ts_minute', 'ts_weekday', 'brand_target_sum', 'brand_count',
#        'cat_0_target_sum', 'cat_0_count', 'cat_1_target_sum', 'cat_1_count',
#        'cat_2_target_sum', 'cat_2_count', 'cat_3_target_sum', 'cat_3_count',
#        'TE_cat_0_target', 'TE_cat_1_target', 'TE_cat_2_target',
#        'TE_cat_3_target', 'relative_price_product', 'relative_price_category',
#        'target'],
#       dtype='object')
#    brand  cat_0  cat_1  cat_2  cat_3       price  ts_hour  ts_minute  \
# 0    234      3      2      2      1   54.029999       15         14
# 1      2      1      1      1      1  870.270020       14         19
# 2      2      6      5      2      1  166.670013        4         32
# 3     20      2      7      4      1  295.989990       13         41
# 4     27      3      2      2      1   43.240002       17         43
#
#    ts_weekday  brand_target_sum  ...  cat_2_count  cat_3_target_sum  \
# 0           6               347  ...       751352           1009432
# 1           3            187853  ...       898095           1009432
# 2           1            187853  ...       751352           1009432
# 3           2              5828  ...        84166           1009432
# 4           1              2815  ...       751352           1009432
#
#    cat_3_count  TE_cat_0_target  TE_cat_1_target  TE_cat_2_target  \
# 0      2460405         0.298127         0.298127         0.339966
# 1      2460405         0.482280         0.481771         0.487952
# 2      2460405         0.382438         0.396645         0.339709
# 3      2460405         0.391197         0.416553         0.420994
# 4      2460405         0.298564         0.298564         0.339709
#
#    TE_cat_3_target  relative_price_product  relative_price_category  target
# 0         0.410503           -2.364262e-01                -0.557799       1
# 1         0.409943           -3.739005e-02                 0.889045       1
# 2         0.409943            2.697176e-02                 0.383894       1
# 3         0.410366           -4.706145e-02                -0.191993       1
# 4         0.409943            1.764430e-07                -0.646108       1
#
# [5 rows x 26 columns]

# %%
# 1.3
ddf.isna()
# Out:
# <dask_cudf.DataFrame | 8 tasks | 4 npartitions>

# %% [markdown]
# ### Step 2: Feature Engineering ###
# Next, we will perform some feature engineering.
#
# **Instructions**: <br>
# 2.1 Modify the `<FIXME>`s only and execute the below cell to `target_encode` the `brand` feature. <br>
# 2.2 Modify the `<FIXME>`s only and execute the cell below to create a `relative_price_brand` feature. In case a price is small or 0, please introduce an `epsilon` to avoid division by zero. <br>
# 2.3 Execute the cell below to persist the data in memory.

# %%
# 2.1
def target_encoding(df, cat): 
    te_df=df.groupby(cat)['target'].mean().reset_index()
    te_df.columns=[cat, cat+'_TE']
    df=df.merge(te_df, on=cat)
    return df

ddf=target_encoding(ddf, 'brand')
ddf.head()
# Out:
#    brand  cat_0  cat_1  cat_2  cat_3       price  ts_hour  ts_minute  \
# 0    234      3      2      2      1   54.029999       15         14
# 1      2      1      1      1      1  870.270020       14         19
# 2      2      6      5      2      1  166.670013        4         32
# 3     20      2      7      4      1  295.989990       13         41
# 4     27      3      2      2      1   43.240002       17         43
#
#    ts_weekday  brand_target_sum  ...  cat_3_target_sum  cat_3_count  \
# 0           6               347  ...           1009432      2460405
# 1           3            187853  ...           1009432      2460405
# 2           1            187853  ...           1009432      2460405
# 3           2              5828  ...           1009432      2460405
# 4           1              2815  ...           1009432      2460405
#
#    TE_cat_0_target  TE_cat_1_target  TE_cat_2_target  TE_cat_3_target  \
# 0         0.298127         0.298127         0.339966         0.410503
# 1         0.482280         0.481771         0.487952         0.409943
# 2         0.382438         0.396645         0.339709         0.409943
# 3         0.391197         0.416553         0.420994         0.410366
# 4         0.298564         0.298564         0.339709         0.409943
#
#    relative_price_product  relative_price_category  target  brand_TE
# 0           -2.364262e-01                -0.557799       1  0.475995
# 1           -3.739005e-02                 0.889045       1  0.481383
# 2            2.697176e-02                 0.383894       1  0.481383
# 3           -4.706145e-02                -0.191993       1  0.463939
# 4            1.764430e-07                -0.646108       1  0.247647
#
# [5 rows x 27 columns]

# %%
# 2.2
def relative_price(df, cat): 
    epsilon=1e-5
    avg_price_df=df.groupby(cat)['price'].mean().reset_index()
    avg_price_df.columns=[cat, 'avg_price_'+cat]
    df=df.merge(avg_price_df, on=cat)
    df['relative_price_'+cat]=df['price']/(df['avg_price_'+cat] + epsilon)
    df=df.drop(columns=['avg_price_'+cat])
    return df

ddf=relative_price(ddf, 'brand')
ddf.head()
# Out:
#    brand  cat_0  cat_1  cat_2  cat_3       price  ts_hour  ts_minute  \
# 0    234      3      2      2      1   54.029999       15         14
# 1      2      1      1      1      1  870.270020       14         19
# 2      2      6      5      2      1  166.670013        4         32
# 3     20      2      7      4      1  295.989990       13         41
# 4     27      3      2      2      1   43.240002       17         43
#
#    ts_weekday  brand_target_sum  ...  cat_3_count  TE_cat_0_target  \
# 0           6               347  ...      2460405         0.298127
# 1           3            187853  ...      2460405         0.482280
# 2           1            187853  ...      2460405         0.382438
# 3           2              5828  ...      2460405         0.391197
# 4           1              2815  ...      2460405         0.298564
#
#    TE_cat_1_target  TE_cat_2_target  TE_cat_3_target  relative_price_product  \
# 0         0.298127         0.339966         0.410503           -2.364262e-01
# 1         0.481771         0.487952         0.409943           -3.739005e-02
# 2         0.396645         0.339709         0.409943            2.697176e-02
# 3         0.416553         0.420994         0.410366           -4.706145e-02
# 4         0.298564         0.339709         0.409943            1.764430e-07
#
#    relative_price_category  target  brand_TE  relative_price_brand
# 0                -0.557799       1  0.475995              0.891264
# 1                 0.889045       1  0.481383              1.177482
# 2                 0.383894       1  0.481383              0.225506
# 3                -0.191993       1  0.463939              3.040803
# 4                -0.646108       1  0.247647              1.065219
#
# [5 rows x 28 columns]

# %%
# 2.3
# DO NOT CHANGE THIS CELL
# persist data
ddf=ddf.persist()
wait(ddf)

print(f'Columns: {ddf.columns}')
# Out:
# Columns: Index(['brand', 'cat_0', 'cat_1', 'cat_2', 'cat_3', 'price', 'ts_hour',
#        'ts_minute', 'ts_weekday', 'brand_target_sum', 'brand_count',
#        'cat_0_target_sum', 'cat_0_count', 'cat_1_target_sum', 'cat_1_count',
#        'cat_2_target_sum', 'cat_2_count', 'cat_3_target_sum', 'cat_3_count',
#        'TE_cat_0_target', 'TE_cat_1_target', 'TE_cat_2_target',
#        'TE_cat_3_target', 'relative_price_product', 'relative_price_category',
#        'target', 'brand_TE', 'relative_price_brand'],
#       dtype='object')

# %% [markdown]
# ### Step 3: Model Training ###
# The next step is to train an `xgboost.dask.XGBoostClassifier`.
#
# **Instructions**: <br>
# 3.1 Execute the below cell to select desired features for training and set as `X`. <br>
# 3.2 Modify the `<FIXME>` only and execute the cell below to set `target` as `y`. <br>
# 3.3 Modify the `<FIXME>` only and execute the cell below to split the dataset into `X_train`, `X_test`, `y_train`, and `y_test`. <br>
# 3.4 Execute the cell below to create `xgb.dask.DaskDMatrix` objects for training and testing as `dtrain` and `dtest`. <br>
# 3.5 Modify the `<FIXME>`s only and execute the cell below to set the XGBoost parameters. For this assessment, please use the `auc` evaluation metric. <br>
# 3.6 Modify the `<FIXME>`s only and execute the cell below to initiate training. <br>
# 3.7 Execute the cell below to view the training and validation history.

# %%
# 3.1
# DO NOT CHANGE THIS CELL
X=ddf.drop(columns=['target']).astype('float32')

# %%
# 3.2
y=ddf['target'].astype('float32')

# %%
# 3.3
X_train, X_test, y_train, y_test=train_test_split(X, y, random_state=42)
X_train, X_test, y_train, y_test=client.persist([X_train, X_test, y_train, y_test])
wait([X_train, X_test, y_train, y_test])
# Out:
# /opt/conda/envs/rapids/lib/python3.9/site-packages/dask_ml/model_selection/_split.py:462: FutureWarning: The default value for 'shuffle' must be specified when splitting DataFrames. In the future DataFrames will automatically be shuffled within blocks prior to splitting. Specify 'shuffle=True' to adopt the future behavior now, or 'shuffle=False' to retain the previous behavior.
#   warnings.warn(
# DoneAndNotDoneFutures(done={<Future: finished, type: cudf.core.series.Series, key: ('split-1-401501715ba64857815396c15730c094', 2)>, <Future: finished, type: cudf.core.series.Series, key: ('split-1-401501715ba64857815396c15730c094', 3)>, <Future: finished, type: cudf.core.dataframe.DataFrame, key: ('split-0-612ec61a9d5f92f103570fd03589ce25', 1)>, <Future: finished, type: cudf.core.dataframe.DataFrame, key: ('split-1-612ec61a9d5f92f103570fd03589ce25', 1)>, <Future: finished, type: cudf.core.dataframe.DataFrame, key: ('split-0-612ec61a9d5f92f103570fd03589ce25', 0)>, <Future: finished, type: cudf.core.series.Series, key: ('split-1-401501715ba64857815396c15730c094', 0)>, <Future: finished, type: cudf.core.dataframe.DataFrame, key: ('split-1-612ec61a9d5f92f103570fd03589ce25', 0)>, <Future: finished, type: cudf.core.dataframe.DataFrame, key: ('split-0-612ec61a9d5f92f103570fd03589ce25', 3)>, <Future: finished, type: cudf.core.dataframe.DataFrame, key: ('split-1-612ec61a9d5f92f103570fd03589ce25', 2)>, <Future: finished, type: cudf.core.series.Series, key: ('split-0-401501715ba64857815396c15730c094', 1)>, <Future: finished, type: cudf.core.series.Series, key: ('split-0-401501715ba64857815396c15730c094', 2)>, <Future: finished, type: cudf.core.series.Series, key: ('split-0-401501715ba64857815396c15730c094', 3)>, <Future: finished, type: cudf.core.dataframe.DataFrame, key: ('split-1-612ec61a9d5f92f103570fd03589ce25', 3)>, <Future: finished, type: cudf.core.series.Series, key: ('split-0-401501715ba64857815396c15730c094', 0)>, <Future: finished, type: cudf.core.dataframe.DataFrame, key: ('split-0-612ec61a9d5f92f103570fd03589ce25', 2)>, <Future: finished, type: cudf.core.series.Series, key: ('split-1-401501715ba64857815396c15730c094', 1)>}, not_done=set())

# %%
# 3.4
# DO NOT CHANGE THIS CELL
dtrain=xgboost.dask.DaskDMatrix(client, X_train, y_train)
dtest=xgboost.dask.DaskDMatrix(client, X_test, y_test)

# %%
# 3.5
xgb_params={ 
    'eval_metric': ['auc'], 
    'objective': 'binary:logistic',
    'tree_method': 'gpu_hist'
}

# %%
# 3.6
# train the model
xgb_dask_clf=xgboost.dask.train(client=client, 
                                params=xgb_params, 
                                dtrain=dtrain,
                                evals=[(dtrain, 'train'), (dtest, 'valid')],
                                num_boost_round=350,
                                early_stopping_rounds=10, 
                                verbose_eval=True
                               )
# Out:
# /opt/conda/envs/rapids/lib/python3.9/site-packages/xgboost/dask.py:856: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [21:52:18] task [xgboost.dask-0]:tcp://127.0.0.1:40689 got new rank 0
# [21:52:18] task [xgboost.dask-1]:tcp://127.0.0.1:39821 got new rank 1
# [21:52:18] task [xgboost.dask-2]:tcp://127.0.0.1:38023 got new rank 2
# [21:52:18] task [xgboost.dask-3]:tcp://127.0.0.1:41043 got new rank 3
# [0]	train-auc:0.60956	valid-auc:0.60836
# [1]	train-auc:0.61163	valid-auc:0.61051
# [2]	train-auc:0.61296	valid-auc:0.61164
# [3]	train-auc:0.61368	valid-auc:0.61236
# [4]	train-auc:0.61437	valid-auc:0.61291
# [5]	train-auc:0.61513	valid-auc:0.61346
# [6]	train-auc:0.61574	valid-auc:0.61404
# [7]	train-auc:0.61618	valid-auc:0.61438
# [8]	train-auc:0.61687	valid-auc:0.61506
# [9]	train-auc:0.61717	valid-auc:0.61530
# [10]	train-auc:0.61821	valid-auc:0.61630
# [11]	train-auc:0.61867	valid-auc:0.61663
# [12]	train-auc:0.61926	valid-auc:0.61717
# [13]	train-auc:0.61953	valid-auc:0.61733
# [14]	train-auc:0.61969	valid-auc:0.61743
# [15]	train-auc:0.61988	valid-auc:0.61751
# [16]	train-auc:0.62043	valid-auc:0.61806
# [17]	train-auc:0.62079	valid-auc:0.61834
# [18]	train-auc:0.62101	valid-auc:0.61851
# [19]	train-auc:0.62120	valid-auc:0.61864
# [20]	train-auc:0.62152	valid-auc:0.61888
# [21]	train-auc:0.62158	valid-auc:0.61892
# [22]	train-auc:0.62188	valid-auc:0.61902
# [23]	train-auc:0.62224	valid-auc:0.61927
# [24]	train-auc:0.62248	valid-auc:0.61938
# [25]	train-auc:0.62254	valid-auc:0.61943
# [26]	train-auc:0.62285	valid-auc:0.61963
# [27]	train-auc:0.62317	valid-auc:0.61982
# [28]	train-auc:0.62339	valid-auc:0.61996
# [29]	train-auc:0.62370	valid-auc:0.62018
# [30]	train-auc:0.62383	valid-auc:0.62026
# [31]	train-auc:0.62401	valid-auc:0.62033
# [32]	train-auc:0.62439	valid-auc:0.62056
# [33]	train-auc:0.62463	valid-auc:0.62068
# [34]	train-auc:0.62496	valid-auc:0.62090
# [35]	train-auc:0.62508	valid-auc:0.62095
# [36]	train-auc:0.62526	valid-auc:0.62107
# [37]	train-auc:0.62546	valid-auc:0.62121
# [38]	train-auc:0.62568	valid-auc:0.62140
# [39]	train-auc:0.62588	valid-auc:0.62151
# [40]	train-auc:0.62597	valid-auc:0.62156
# [41]	train-auc:0.62604	valid-auc:0.62159
# [42]	train-auc:0.62629	valid-auc:0.62174
# [43]	train-auc:0.62655	valid-auc:0.62197
# [44]	train-auc:0.62684	valid-auc:0.62216
# [45]	train-auc:0.62695	valid-auc:0.62221
# [46]	train-auc:0.62707	valid-auc:0.62227
# [47]	train-auc:0.62719	valid-auc:0.62230
# [48]	train-auc:0.62748	valid-auc:0.62251
# [49]	train-auc:0.62753	valid-auc:0.62253
# [50]	train-auc:0.62785	valid-auc:0.62278
# [51]	train-auc:0.62805	valid-auc:0.62281
# [52]	train-auc:0.62815	valid-auc:0.62283
# [53]	train-auc:0.62826	valid-auc:0.62286
# [54]	train-auc:0.62843	valid-auc:0.62298
# [55]	train-auc:0.62868	valid-auc:0.62323
# [56]	train-auc:0.62885	valid-auc:0.62333
# [57]	train-auc:0.62912	valid-auc:0.62342
# [58]	train-auc:0.62924	valid-auc:0.62348
# [59]	train-auc:0.62946	valid-auc:0.62359
# [60]	train-auc:0.62964	valid-auc:0.62365
# [61]	train-auc:0.62993	valid-auc:0.62383
# [62]	train-auc:0.63001	valid-auc:0.62389
# [63]	train-auc:0.63004	valid-auc:0.62389
# [64]	train-auc:0.63013	valid-auc:0.62392
# [65]	train-auc:0.63022	valid-auc:0.62393
# [66]	train-auc:0.63033	valid-auc:0.62398
# [67]	train-auc:0.63051	valid-auc:0.62408
# [68]	train-auc:0.63082	valid-auc:0.62425
# [69]	train-auc:0.63108	valid-auc:0.62444
# [70]	train-auc:0.63120	valid-auc:0.62445
# [71]	train-auc:0.63141	valid-auc:0.62460
# [72]	train-auc:0.63155	valid-auc:0.62465
# [73]	train-auc:0.63163	valid-auc:0.62468
# [74]	train-auc:0.63182	valid-auc:0.62476
# [75]	train-auc:0.63192	valid-auc:0.62477
# [76]	train-auc:0.63209	valid-auc:0.62491
# [77]	train-auc:0.63227	valid-auc:0.62498
# [78]	train-auc:0.63248	valid-auc:0.62505
# [79]	train-auc:0.63254	valid-auc:0.62506
# [80]	train-auc:0.63258	valid-auc:0.62506
# [81]	train-auc:0.63277	valid-auc:0.62521
# [82]	train-auc:0.63293	valid-auc:0.62532
# [83]	train-auc:0.63314	valid-auc:0.62543
# [84]	train-auc:0.63326	valid-auc:0.62550
# [85]	train-auc:0.63346	valid-auc:0.62560
# [86]	train-auc:0.63361	valid-auc:0.62568
# [87]	train-auc:0.63372	valid-auc:0.62573
# [88]	train-auc:0.63382	valid-auc:0.62577
# [89]	train-auc:0.63395	valid-auc:0.62581
# [90]	train-auc:0.63411	valid-auc:0.62586
# [91]	train-auc:0.63423	valid-auc:0.62591
# [92]	train-auc:0.63440	valid-auc:0.62600
# [93]	train-auc:0.63459	valid-auc:0.62614
# [94]	train-auc:0.63478	valid-auc:0.62624
# [95]	train-auc:0.63486	valid-auc:0.62629
# [96]	train-auc:0.63492	valid-auc:0.62628
# [97]	train-auc:0.63494	valid-auc:0.62628
# [98]	train-auc:0.63507	valid-auc:0.62632
# [99]	train-auc:0.63520	valid-auc:0.62638
# [100]	train-auc:0.63534	valid-auc:0.62646
# [101]	train-auc:0.63545	valid-auc:0.62652
# [102]	train-auc:0.63563	valid-auc:0.62657
# [103]	train-auc:0.63580	valid-auc:0.62668
# [104]	train-auc:0.63596	valid-auc:0.62670
# [105]	train-auc:0.63607	valid-auc:0.62674
# [106]	train-auc:0.63618	valid-auc:0.62676
# [107]	train-auc:0.63637	valid-auc:0.62686
# [108]	train-auc:0.63651	valid-auc:0.62692
# [109]	train-auc:0.63656	valid-auc:0.62692
# [110]	train-auc:0.63663	valid-auc:0.62694
# [111]	train-auc:0.63674	valid-auc:0.62695
# [112]	train-auc:0.63691	valid-auc:0.62702
# [113]	train-auc:0.63712	valid-auc:0.62712
# [114]	train-auc:0.63724	valid-auc:0.62714
# [115]	train-auc:0.63733	valid-auc:0.62717
# [116]	train-auc:0.63748	valid-auc:0.62722
# [117]	train-auc:0.63756	valid-auc:0.62723
# [118]	train-auc:0.63774	valid-auc:0.62742
# [119]	train-auc:0.63785	valid-auc:0.62737
# [120]	train-auc:0.63798	valid-auc:0.62743
# [121]	train-auc:0.63812	valid-auc:0.62747
# [122]	train-auc:0.63832	valid-auc:0.62761
# [123]	train-auc:0.63848	valid-auc:0.62769
# [124]	train-auc:0.63867	valid-auc:0.62771
# [125]	train-auc:0.63882	valid-auc:0.62784
# [126]	train-auc:0.63892	valid-auc:0.62784
# [127]	train-auc:0.63904	valid-auc:0.62790
# [128]	train-auc:0.63915	valid-auc:0.62791
# [129]	train-auc:0.63921	valid-auc:0.62791
# [130]	train-auc:0.63936	valid-auc:0.62795
# [131]	train-auc:0.63943	valid-auc:0.62798
# [132]	train-auc:0.63960	valid-auc:0.62807
# [133]	train-auc:0.63971	valid-auc:0.62815
# [134]	train-auc:0.63977	valid-auc:0.62815
# [135]	train-auc:0.63993	valid-auc:0.62825
# [136]	train-auc:0.64007	valid-auc:0.62833
# [137]	train-auc:0.64017	valid-auc:0.62832
# [138]	train-auc:0.64033	valid-auc:0.62835
# [139]	train-auc:0.64046	valid-auc:0.62830
# [140]	train-auc:0.64059	valid-auc:0.62834
# [141]	train-auc:0.64065	valid-auc:0.62834
# [142]	train-auc:0.64072	valid-auc:0.62836
# [143]	train-auc:0.64084	valid-auc:0.62844
# [144]	train-auc:0.64095	valid-auc:0.62849
# [145]	train-auc:0.64103	valid-auc:0.62851
# [146]	train-auc:0.64113	valid-auc:0.62853
# [147]	train-auc:0.64132	valid-auc:0.62867
# [148]	train-auc:0.64136	valid-auc:0.62865
# [149]	train-auc:0.64150	valid-auc:0.62872
# [150]	train-auc:0.64159	valid-auc:0.62873
# [151]	train-auc:0.64172	valid-auc:0.62879
# [152]	train-auc:0.64184	valid-auc:0.62882
# [153]	train-auc:0.64193	valid-auc:0.62883
# [154]	train-auc:0.64199	valid-auc:0.62882
# [155]	train-auc:0.64205	valid-auc:0.62884
# [156]	train-auc:0.64212	valid-auc:0.62887
# [157]	train-auc:0.64221	valid-auc:0.62890
# [158]	train-auc:0.64235	valid-auc:0.62897
# [159]	train-auc:0.64246	valid-auc:0.62899
# [160]	train-auc:0.64260	valid-auc:0.62910
# [161]	train-auc:0.64271	valid-auc:0.62911
# [162]	train-auc:0.64284	valid-auc:0.62915
# [163]	train-auc:0.64303	valid-auc:0.62923
# [164]	train-auc:0.64319	valid-auc:0.62930
# [165]	train-auc:0.64332	valid-auc:0.62930
# [166]	train-auc:0.64343	valid-auc:0.62934
# [167]	train-auc:0.64355	valid-auc:0.62940
# [168]	train-auc:0.64364	valid-auc:0.62942
# [169]	train-auc:0.64375	valid-auc:0.62944
# [170]	train-auc:0.64381	valid-auc:0.62946
# [171]	train-auc:0.64393	valid-auc:0.62947
# [172]	train-auc:0.64401	valid-auc:0.62947
# [173]	train-auc:0.64410	valid-auc:0.62948
# [174]	train-auc:0.64415	valid-auc:0.62950
# [175]	train-auc:0.64423	valid-auc:0.62951
# [176]	train-auc:0.64437	valid-auc:0.62962
# [177]	train-auc:0.64447	valid-auc:0.62963
# [178]	train-auc:0.64457	valid-auc:0.62965
# [179]	train-auc:0.64471	valid-auc:0.62968
# [180]	train-auc:0.64484	valid-auc:0.62973
# [181]	train-auc:0.64498	valid-auc:0.62975
# [182]	train-auc:0.64504	valid-auc:0.62976
# [183]	train-auc:0.64512	valid-auc:0.62973
# [184]	train-auc:0.64523	valid-auc:0.62979
# [185]	train-auc:0.64530	valid-auc:0.62983
# [186]	train-auc:0.64535	valid-auc:0.62982
# [187]	train-auc:0.64548	valid-auc:0.62986
# [188]	train-auc:0.64561	valid-auc:0.62994
# [189]	train-auc:0.64568	valid-auc:0.62998
# [190]	train-auc:0.64580	valid-auc:0.63006
# [191]	train-auc:0.64594	valid-auc:0.63011
# [192]	train-auc:0.64600	valid-auc:0.63011
# [193]	train-auc:0.64611	valid-auc:0.63016
# [194]	train-auc:0.64617	valid-auc:0.63015
# [195]	train-auc:0.64627	valid-auc:0.63019
# [196]	train-auc:0.64644	valid-auc:0.63026
# [197]	train-auc:0.64657	valid-auc:0.63035
# [198]	train-auc:0.64667	valid-auc:0.63040
# [199]	train-auc:0.64680	valid-auc:0.63042
# [200]	train-auc:0.64693	valid-auc:0.63042
# [201]	train-auc:0.64704	valid-auc:0.63051
# [202]	train-auc:0.64723	valid-auc:0.63064
# [203]	train-auc:0.64737	valid-auc:0.63073
# [204]	train-auc:0.64745	valid-auc:0.63070
# [205]	train-auc:0.64753	valid-auc:0.63071
# [206]	train-auc:0.64760	valid-auc:0.63073
# [207]	train-auc:0.64768	valid-auc:0.63076
# [208]	train-auc:0.64779	valid-auc:0.63076
# [209]	train-auc:0.64784	valid-auc:0.63079
# [210]	train-auc:0.64794	valid-auc:0.63083
# [211]	train-auc:0.64808	valid-auc:0.63093
# [212]	train-auc:0.64817	valid-auc:0.63092
# [213]	train-auc:0.64829	valid-auc:0.63098
# [214]	train-auc:0.64836	valid-auc:0.63097
# [215]	train-auc:0.64844	valid-auc:0.63099
# [216]	train-auc:0.64848	valid-auc:0.63099
# [217]	train-auc:0.64855	valid-auc:0.63102
# [218]	train-auc:0.64861	valid-auc:0.63105
# [219]	train-auc:0.64867	valid-auc:0.63106
# [220]	train-auc:0.64875	valid-auc:0.63110
# [221]	train-auc:0.64884	valid-auc:0.63112
# [222]	train-auc:0.64895	valid-auc:0.63114
# [223]	train-auc:0.64906	valid-auc:0.63117
# [224]	train-auc:0.64913	valid-auc:0.63117
# [225]	train-auc:0.64920	valid-auc:0.63117
# [226]	train-auc:0.64929	valid-auc:0.63117
# [227]	train-auc:0.64939	valid-auc:0.63119
# [228]	train-auc:0.64950	valid-auc:0.63121
# [229]	train-auc:0.64955	valid-auc:0.63121
# [230]	train-auc:0.64968	valid-auc:0.63126
# [231]	train-auc:0.64977	valid-auc:0.63131
# [232]	train-auc:0.64986	valid-auc:0.63134
# [233]	train-auc:0.64998	valid-auc:0.63137
# [234]	train-auc:0.65007	valid-auc:0.63138
# [235]	train-auc:0.65016	valid-auc:0.63140
# [236]	train-auc:0.65022	valid-auc:0.63140
# [237]	train-auc:0.65028	valid-auc:0.63140
# [238]	train-auc:0.65035	valid-auc:0.63140
# [239]	train-auc:0.65039	valid-auc:0.63140
# [240]	train-auc:0.65041	valid-auc:0.63141
# [241]	train-auc:0.65055	valid-auc:0.63150
# [242]	train-auc:0.65063	valid-auc:0.63152
# [243]	train-auc:0.65075	valid-auc:0.63154
# [244]	train-auc:0.65081	valid-auc:0.63155
# [245]	train-auc:0.65090	valid-auc:0.63160
# [246]	train-auc:0.65100	valid-auc:0.63158
# [247]	train-auc:0.65107	valid-auc:0.63158
# [248]	train-auc:0.65114	valid-auc:0.63158
# [249]	train-auc:0.65127	valid-auc:0.63161
# [250]	train-auc:0.65136	valid-auc:0.63164
# [251]	train-auc:0.65147	valid-auc:0.63167
# [252]	train-auc:0.65156	valid-auc:0.63168
# [253]	train-auc:0.65161	valid-auc:0.63167
# [254]	train-auc:0.65173	valid-auc:0.63167
# [255]	train-auc:0.65183	valid-auc:0.63168
# [256]	train-auc:0.65188	valid-auc:0.63168
# [257]	train-auc:0.65195	valid-auc:0.63173
# [258]	train-auc:0.65204	valid-auc:0.63181
# [259]	train-auc:0.65208	valid-auc:0.63181
# [260]	train-auc:0.65221	valid-auc:0.63194
# [261]	train-auc:0.65229	valid-auc:0.63201
# [262]	train-auc:0.65241	valid-auc:0.63202
# [263]	train-auc:0.65251	valid-auc:0.63205
# [264]	train-auc:0.65256	valid-auc:0.63206
# [265]	train-auc:0.65266	valid-auc:0.63213
# [266]	train-auc:0.65273	valid-auc:0.63215
# [267]	train-auc:0.65282	valid-auc:0.63217
# [268]	train-auc:0.65291	valid-auc:0.63218
# [269]	train-auc:0.65302	valid-auc:0.63223
# [270]	train-auc:0.65307	valid-auc:0.63225
# [271]	train-auc:0.65314	valid-auc:0.63223
# [272]	train-auc:0.65324	valid-auc:0.63228
# [273]	train-auc:0.65332	valid-auc:0.63234
# [274]	train-auc:0.65341	valid-auc:0.63238
# [275]	train-auc:0.65354	valid-auc:0.63243
# [276]	train-auc:0.65362	valid-auc:0.63246
# [277]	train-auc:0.65375	valid-auc:0.63251
# [278]	train-auc:0.65384	valid-auc:0.63254
# [279]	train-auc:0.65393	valid-auc:0.63257
# [280]	train-auc:0.65401	valid-auc:0.63259
# [281]	train-auc:0.65415	valid-auc:0.63263
# [282]	train-auc:0.65424	valid-auc:0.63264
# [283]	train-auc:0.65437	valid-auc:0.63265
# [284]	train-auc:0.65447	valid-auc:0.63274
# [285]	train-auc:0.65457	valid-auc:0.63280
# [286]	train-auc:0.65469	valid-auc:0.63284
# [287]	train-auc:0.65475	valid-auc:0.63286
# [288]	train-auc:0.65487	valid-auc:0.63290
# [289]	train-auc:0.65489	valid-auc:0.63290
# [290]	train-auc:0.65495	valid-auc:0.63291
# [291]	train-auc:0.65505	valid-auc:0.63294
# [292]	train-auc:0.65510	valid-auc:0.63293
# [293]	train-auc:0.65519	valid-auc:0.63295
# [294]	train-auc:0.65523	valid-auc:0.63295
# [295]	train-auc:0.65527	valid-auc:0.63294
# [296]	train-auc:0.65532	valid-auc:0.63296
# [297]	train-auc:0.65541	valid-auc:0.63299
# [298]	train-auc:0.65549	valid-auc:0.63299
# [299]	train-auc:0.65553	valid-auc:0.63297
# [300]	train-auc:0.65560	valid-auc:0.63300
# [301]	train-auc:0.65571	valid-auc:0.63307
# [302]	train-auc:0.65582	valid-auc:0.63310
# [303]	train-auc:0.65589	valid-auc:0.63312
# [304]	train-auc:0.65598	valid-auc:0.63313
# [305]	train-auc:0.65613	valid-auc:0.63319
# [306]	train-auc:0.65620	valid-auc:0.63320
# [307]	train-auc:0.65628	valid-auc:0.63323
# [308]	train-auc:0.65637	valid-auc:0.63327
# [309]	train-auc:0.65644	valid-auc:0.63328
# [310]	train-auc:0.65654	valid-auc:0.63329
# [311]	train-auc:0.65660	valid-auc:0.63327
# [312]	train-auc:0.65665	valid-auc:0.63329
# [313]	train-auc:0.65673	valid-auc:0.63333
# [314]	train-auc:0.65677	valid-auc:0.63333
# [315]	train-auc:0.65684	valid-auc:0.63333
# [316]	train-auc:0.65690	valid-auc:0.63331
# [317]	train-auc:0.65698	valid-auc:0.63332
# [318]	train-auc:0.65707	valid-auc:0.63336
# [319]	train-auc:0.65712	valid-auc:0.63337
# [320]	train-auc:0.65717	valid-auc:0.63339
# [321]	train-auc:0.65718	valid-auc:0.63339
# [322]	train-auc:0.65723	valid-auc:0.63341
# [323]	train-auc:0.65733	valid-auc:0.63346
# [324]	train-auc:0.65746	valid-auc:0.63349
# [325]	train-auc:0.65754	valid-auc:0.63353
# [326]	train-auc:0.65761	valid-auc:0.63352
# [327]	train-auc:0.65763	valid-auc:0.63351
# [328]	train-auc:0.65775	valid-auc:0.63355
# [329]	train-auc:0.65783	valid-auc:0.63355
# [330]	train-auc:0.65790	valid-auc:0.63358
# [331]	train-auc:0.65798	valid-auc:0.63362
# [332]	train-auc:0.65802	valid-auc:0.63364
# [333]	train-auc:0.65811	valid-auc:0.63367
# [334]	train-auc:0.65817	valid-auc:0.63366
# [335]	train-auc:0.65829	valid-auc:0.63370
# [336]	train-auc:0.65837	valid-auc:0.63373
# [337]	train-auc:0.65846	valid-auc:0.63376
# [338]	train-auc:0.65850	valid-auc:0.63375
# [339]	train-auc:0.65857	valid-auc:0.63377
# [340]	train-auc:0.65864	valid-auc:0.63378
# [341]	train-auc:0.65869	valid-auc:0.63379
# [342]	train-auc:0.65874	valid-auc:0.63381
# [343]	train-auc:0.65887	valid-auc:0.63387
# [344]	train-auc:0.65896	valid-auc:0.63390
# [345]	train-auc:0.65904	valid-auc:0.63392
# [346]	train-auc:0.65911	valid-auc:0.63393
# [347]	train-auc:0.65921	valid-auc:0.63393
# [348]	train-auc:0.65924	valid-auc:0.63393
# [349]	train-auc:0.65931	valid-auc:0.63397

# %%
# 3.6
# DO NOT CHANGE THIS CELL
# plot history
history=xgb_dask_clf['history']

plt.plot(history['train']['auc'], label='Train Score (AUC)')
plt.plot(history['valid']['auc'], label='Test Score (AUC)')

plt.xlabel('Iteration')
plt.ylabel('Model Performance')
plt.legend()
plt.show()

# %% [markdown]
# ### Step 4: Model Persistence ###
# The last step for the assessment is to save the model for grading. You should improve the model until the AUC ROC is above 60%. Once completed, you should submit the model for grading.
#
# **Instructions**: <br>
# 4.1 Execute the cell below to save the model in JSON format. <br>

# %%
# 4.1
# DO NOT CHANGE THIS CELL
# save model
xgb_dask_clf['booster'].save_model('my_assessment/model.json')

# %% [markdown]
# ### Grade Your Code ###
# If you have trained the model and completed model evaluation successfully, save changes to the notebook and revisit the webpage where you launched this interactive environment. Click on the "**ASSESS TASK**" button as shown in the screenshot below. Doing so will give you credit for this part of the lab that counts towards earning a certificate of competency for the entire course.
#
# <p><img src='images/credit.png' width=720></p>

# %% [markdown]
# <a href="https://www.nvidia.com/dli"><img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/></a>
